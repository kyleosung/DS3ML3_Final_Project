# %%
import pandas as pd

df = pd.read_csv('../Data/DataTrain/Chess_Jan_ab', 
                        usecols = ['board', 'cp', 'white_active', 'white_elo', 'black_elo'], 
                        dtype = {'white_elo': 'uint16', 'black_elo': 'uint16', 'cp': 'float32', 'white_active': 'bool'},
)

# %%
df
# Out:
#        white_elo  black_elo    cp  white_active  \
# 0           1426       2115 -0.76         False
# 1           1426       2115 -0.71          True
# 2           1426       2115 -0.77         False
# 3           1426       2115 -0.78          True
# 4           1426       2115 -0.69         False
# ...          ...        ...   ...           ...
# 99995       1361       1367  0.82         False
# 99996       1361       1367  3.47          True
# 99997       1361       1367  3.63         False
# 99998       1361       1367  6.68          True
# 99999       1361       1367  2.38         False
#
#                                                    board
# 0      rnbqkb1r/pp3ppp/4pn2/2p5/2PpN3/1P4P1/P2PPPBP/R...
# 1      rnbqkb1r/pp3ppp/4p3/2p5/2Ppn3/1P4P1/P2PPPBP/R1...
# 2      rnbqkb1r/pp3ppp/4p3/2p5/2PpB3/1P4P1/P2PPP1P/R1...
# 3      rnbqk2r/pp3ppp/3bp3/2p5/2PpB3/1P4P1/P2PPP1P/R1...
# 4      rnbqk2r/pp3ppp/3bp3/2p5/2PpB3/1P1P2P1/P3PP1P/R...
# ...
